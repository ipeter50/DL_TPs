# %% [markdown]
# # Credits
# > This code is a slight modification to a translation (TensorFlow --> PyTorch) of a previous version of the [02456](http://kurser.dtu.dk/course/02456) course material.
# > [Original repo link (TensorFlow)](https://github.com/DeepLearningDTU/02456-deep-learning).
# > [Translated repo link (PyTorch)](https://github.com/munkai/pytorch-tutorial/tree/master/2_intermediate).

# %%
import torch
from torch.autograd import Variable
from torch.nn.parameter import Parameter
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init
import random
# %matplotlib inline
import mpld3
mpld3.enable_notebook()
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # MNIST dataset
# MNIST is a dataset that is often used for benchmarking. The MNIST dataset consists of 70,000 images of handwritten digits from 0-9. The dataset is split into a 50,000 images training set, 10,000 images validation set and 10,000 images test set. The images are 28x28 pixels, where each pixel represents a normalised value between 0-255 (0=black and 255=white).
#
# ![MNIST.Exampel](../static_files/mnist.png)
#
#
# ## Primer
# We use a feedforward neural network to classify the 28x28 mnist images. `num_features` is therefore $28 * 28=784$, i.e. we represent each image as a vector. The ordering of the pixels in the vector does not matter, so we could permutate all images using the same permutation and still get the same performance. (You are of course encouraged to try this using ``numpy.random.permutation`` to get a random permutation. This task is therefore called the _permutation invariant_ MNIST. Obviously this throws away a lot of structure in the data. In the next module we'll fix this with the convolutional neural network wich encodes prior knowledgde about data that has either spatial or temporal structure.

# %% [markdown]
# ## MNIST
# First let's load the MNIST dataset and plot a few examples:

# %%
# !if [ ! -f mnist.npz ]; then wget -N https://raw.githubusercontent.com/DeepLearningDTU/02456-deep-learning-with-PyTorch/master/static_files/mnist.npz; else echo "mnist.npz already downloaded"; fi
# Out:
# ! ‚tait inattendu.

# %%
#To speed up training we'll only work on a subset of the data
data = np.load('mnist.npz')
num_classes = 10
x_train = data['X_train'][:1000].astype('float32')
targets_train = data['y_train'][:1000].astype('int32')

x_valid = data['X_valid'][:500].astype('float32')
targets_valid = data['y_valid'][:500].astype('int32')

x_test = data['X_test'][:500].astype('float32')
targets_test = data['y_test'][:500].astype('int32')

print("Information on dataset")
print("x_train", x_train.shape)
print("targets_train", targets_train.shape)
print("x_valid", x_valid.shape)
print("targets_valid", targets_valid.shape)
print("x_test", x_test.shape)
print("targets_test", targets_test.shape)
# Out:
# Information on dataset
# x_train (1000, 784)
# targets_train (1000,)
# x_valid (500, 784)
# targets_valid (500,)
# x_test (500, 784)
# targets_test (500,)

# %%
data

# %%
#plot a few MNIST examples
idx, dim, classes = 0, 28, 10
# create empty canvas
canvas = np.zeros((dim*classes, classes*dim))

# fill with tensors
for i in range(classes):
    for j in range(classes):
        canvas[i*dim:(i+1)*dim, j*dim:(j+1)*dim] = x_train[idx].reshape((dim, dim))
        idx += 1

# visualize matrix of tensors as gray scale image
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(canvas, cmap='gray')
plt.title('MNIST handwritten digits')
plt.show()

# %% [markdown]
# ## Model
#
# One of the large challenges in deep learning is the amount of hyperparameters that needs to be selected, and the lack of a good principled way of selecting them.
# Hyperparameters can be found by experience (guessing) or some search procedure (often quite slow).
# Random search is easy to implement and performs decent: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf .
# More advanced search procedures include [Spearmint](https://github.com/JasperSnoek/spearmint) and many others.
#
# **In practice a lot of trial and error is almost always involved.** This can be frustrating and time consuming, but the best thing to do is to think as a scientist, and go about it in a ordered manner --> monitor as much as you can, take notes, and be deliberate!
#
# Below are some guidelines that you can use as a starting point to some of the most important hyperparameters.
# (*regularization* is also very important, but will be covered later.)
#
#
# ### Ballpark estimates of hyperparameters
# __Number of hidden units and network structure:__
# You'll have to experiment. One rarely goes below 512 units for feedforward networks (unless your are training on CPU...).
# There's some research into stochastic depth networks: https://arxiv.org/pdf/1603.09382v2.pdf, but in general this is trial and error.
#
# __Parameter initialization:__
# Parameter initialization is extremely important.
# PyTorch has a lot of different initializers, check the [PyTorch API](http://pytorch.org/docs/master/nn.html#torch-nn-init). Often used initializer are
# 1. Kaming He
# 2. Xavier Glorot
# 3. Uniform or Normal with small scale (0.1 - 0.01)
# 4. Orthogonal (this usually works very well for RNNs)
#
# Bias is nearly always initialized to zero using the [torch.nn.init.constant(tensor, val)](http://pytorch.org/docs/master/nn.html#torch.nn.init.constant)
#
# __Mini-batch size:__
# Usually people use 16-256. Bigger is not allways better. With smaller mini-batch size you get more updates and your model might converge faster. Also small batch sizes use less memory, which means you can train a model with more parameters.
#
# __Nonlinearity:__ [The most commonly used nonliearities are](http://pytorch.org/docs/master/nn.html#non-linear-activations)
# 1. ReLU
# 2. Leaky ReLU
# 3. Elu
# 3. Sigmoid squash the output [0, 1], and are used if your output is binary (not used in the hidden layers)
# 4. Tanh is similar to sigmoid, but squashes in [-1, 1]. It is rarely used any more.
# 4. Softmax normalizes the the output to 1, and is used as output if you have a classification problem
#
# See the plot below.
#
# __Optimizer and learning rate:__
# 1. SGD + Momentum: learning rate 1.0 - 0.1
# 2. ADAM: learning rate 3*1e-4 - 1e-5
# 3. RMSPROP: somewhere between SGD and ADAM

# %%
# Illustrate different output units
x = np.linspace(-6, 6, 100)
units = {
    "ReLU": lambda x: np.maximum(0, x),
    "Leaky ReLU": lambda x: np.maximum(0, x) + 0.1 * np.minimum(0, x),
    "Elu": lambda x: (x > 0) * x + (1 - (x > 0)) * (np.exp(x) - 1),
    "Sigmoid": lambda x: (1 + np.exp(-x))**(-1),
    "tanh": lambda x: (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
}

plt.figure(figsize=(5, 5))
[plt.plot(x, unit(x), label=unit_name, lw=2) for unit_name, unit in units.items()]
plt.legend(loc=2, fontsize=16)
plt.title('Non-linearities', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])

# assert that all class probablities sum to one
softmax = lambda x: np.exp(x) / np.sum(np.exp(x))
print("softmax should sum to one (approxiamtely):", np.sum(softmax(x)))
# Out:
# softmax should sum to one (approxiamtely): 1.0

# %%
#Hyperparameters
num_classes = 10
num_l1 = 30
num_l2 = 30
num_l3 = 64
num_features = x_train.shape[1]

# define network
class Net(nn.Module):

    def __init__(self, num_features, num_hidden, num_output):
        super(Net, self).__init__()  
        # input layer
        self.W_1 = Parameter(init.kaiming_normal_(torch.Tensor(num_l1, num_features))) #changing weights initialization to Kaiming He's
        self.b_1 = Parameter(init.constant_(torch.Tensor(num_l1), 0))
        
        # adding batchnorm
        self.bn_1 = nn.BatchNorm1d(num_l1) # adding Batchnorm to the network
        
        # hidden layer
        self.W_2 = Parameter(init.kaiming_normal_(torch.Tensor(num_output, num_l1))) #changing weights initialization to Kaiming He's
        self.b_2 = Parameter(init.constant_(torch.Tensor(num_output), 0))
        
        # adding batchnorm
        #self.bn_2 = nn.BatchNorm1d(num_l2) # adding Batchnorm to the network
        
        #hidden layer
        #self.W_3 = Parameter(init.kaiming_normal_(torch.Tensor(num_output, num_l2))) #changing weights initialization to Kaiming He's
        #self.b_3 = Parameter(init.constant_(torch.Tensor(num_output), 0))
        
        # adding batchnorm
        #self.bn_3 = nn.BatchNorm1d(num_l3) # adding Batchnorm to the network
        
        #output layer
       # self.W_4 = Parameter(init.kaiming_normal_(torch.Tensor(num_output, num_l3))) #changing weights initialization to Kaiming He's
       #self.b_4 = Parameter(init.constant_(torch.Tensor(num_output), 0))
        
        # define activation function in constructor
        self.activation = torch.nn.ReLU() # changing activation function to ReLU

    def forward(self, x):
        
        x = F.linear(x, self.W_1, self.b_1)
        #x = self.bn_1(x) # adding Batchnorm to the network
        x = self.activation(x)
        #x = nn.Dropout(p=0.1)(x) # adding Dropout to the network
        
        
        ##### Extra layers #####
        
        x = F.linear(x, self.W_2, self.b_2)
        #x = self.bn_2(x) # adding Batchnorm to the network
        #x = self.activation(x)
        #x = nn.Dropout(p=0.2)(x) # adding Dropout to the network
        
       # x = F.linear(x, self.W_3, self.b_3)
       # x = self.bn_3(x) # adding Batchnorm to the network
       # x = self.activation(x)
       # x = nn.Dropout(p=0.2)(x) # adding Dropout to the network
        
        ##### Extra layers #####
        
        # No batchnorm nor dropout on the output layer
       # x = F.linear(x, self.W_4, self.b_4)
        return F.softmax(x, dim=1)
        

net = Net(num_features, num_l1, num_classes).cuda()

# %%
optimizer = optim.Adam(net.parameters(), lr=0.0001, weight_decay = 1e-5) # , weight_decay = 1e-8 changing optimizer to ADAM and adding L2 regularization (weight decay)
#optimizer = optim.SGD(net.parameters(), lr=0.3, momentum = 0.9, weight_decay = 8e-5) # adding momentum to SGD optimizer


criterion = nn.CrossEntropyLoss()

# %%
#Test the forward pass with dummy data
x = np.random.normal(0, 1, (45, dim*dim)).astype('float32')

print(net(Variable(torch.from_numpy(x).cuda())).size())
# Out:
# torch.Size([45, 10])

# %% [markdown]
# # Build the training loop
#
# We train the network by calculating the gradient w.r.t the cost function and update the parameters in direction of the negative gradient.
#
#
# When training neural network you always use mini batches. Instead of calculating the average gradient using the entire dataset you approximate the gradient using a mini-batch of typically 16 to 256 samples. The paramters are updated after each mini batch. Networks converge much faster using mini batches because the parameters are updated more often.
#
# We build a loop that iterates over the training data. Remember that the parameters are updated each time ``optimizer.step()`` is called.

# %%
# we could have done this ourselves,
# but we should be aware of sklearn and it's tools
from sklearn.metrics import accuracy_score

# setting hyperparameters and gettings epoch sizes
batch_size = 100
num_epochs = 400
num_samples_train = x_train.shape[0]
num_batches_train = num_samples_train // batch_size
num_samples_valid = x_valid.shape[0]
num_batches_valid = num_samples_valid // batch_size

# setting up lists for handling loss/accuracy
train_acc, train_loss = [], []
valid_acc, valid_loss = [], []
test_acc, test_loss = [], []
cur_loss = 0
losses = []


get_slice = lambda i, size: range(i * size, (i + 1) * size)

for epoch in range(num_epochs):
    # Forward -> Backprob -> Update params
    ## Train
    
    randomize = np.arange(len(x_train))
    np.random.shuffle(randomize)
    x_train = x_train[randomize]
    targets_train = targets_train[randomize]
    
    
    cur_loss = 0
    net.train()
    for i in range(num_batches_train):
        slce = get_slice(i, batch_size)
        x_batch = Variable(torch.from_numpy(x_train[slce])).cuda()
        output = net(x_batch)
        
        # compute gradients given loss
        target_batch = Variable(torch.from_numpy(targets_train[slce]).long()).cuda()
        
       


        batch_loss = criterion(output, target_batch)
       
        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()
        
        cur_loss += batch_loss   
    losses.append(cur_loss / batch_size)

    net.eval()

    ### Evaluate training
    train_preds, train_targs = [], []
    for i in range(num_batches_train):
        slce = get_slice(i, batch_size)
        x_batch = Variable(torch.from_numpy(x_train[slce])).cuda()

        output = net(x_batch)
        preds = torch.max(output, 1)[1]

        train_targs += list(targets_train[slce])
        train_preds += list(preds.data.cpu().numpy())

    ### Evaluate validation
    val_preds, val_targs = [], []
    for i in range(num_batches_valid):
        slce = get_slice(i, batch_size)
        x_batch = Variable(torch.from_numpy(x_valid[slce])).cuda()

        output = net(x_batch)
        preds = torch.max(output, 1)[1]
        val_preds += list(preds.data.cpu().numpy())
        val_targs += list(targets_valid[slce])

    train_acc_cur = accuracy_score(train_targs, train_preds)
    valid_acc_cur = accuracy_score(val_targs, val_preds)

    train_acc.append(train_acc_cur)
    valid_acc.append(valid_acc_cur)

    if epoch % 10 == 0:
        print("Epoch %2i : Train Loss %f , Train acc %f, Valid acc %f" % (
                epoch+1, losses[-1], train_acc_cur, valid_acc_cur))

epoch = np.arange(len(train_acc))
plt.figure()
plt.plot(epoch, train_acc, 'r', epoch, valid_acc, 'b')
plt.legend(['Train Accucary','Validation Accuracy'])
plt.xlabel('Updates'), plt.ylabel('Acc')
# Out:
# Epoch  1 : Train Loss 0.150053 , Train acc 0.976000, Valid acc 0.854000
# Epoch 11 : Train Loss 0.149929 , Train acc 0.976000, Valid acc 0.852000
# Epoch 21 : Train Loss 0.149817 , Train acc 0.977000, Valid acc 0.854000
# Epoch 31 : Train Loss 0.149717 , Train acc 0.977000, Valid acc 0.852000
# Epoch 41 : Train Loss 0.149626 , Train acc 0.977000, Valid acc 0.854000
# Epoch 51 : Train Loss 0.149542 , Train acc 0.977000, Valid acc 0.850000
# Epoch 61 : Train Loss 0.149465 , Train acc 0.977000, Valid acc 0.850000
# Epoch 71 : Train Loss 0.149392 , Train acc 0.977000, Valid acc 0.852000
# Epoch 81 : Train Loss 0.149325 , Train acc 0.977000, Valid acc 0.850000
# Epoch 91 : Train Loss 0.149260 , Train acc 0.977000, Valid acc 0.850000
# Epoch 101 : Train Loss 0.149200 , Train acc 0.977000, Valid acc 0.850000
# Epoch 111 : Train Loss 0.149141 , Train acc 0.977000, Valid acc 0.850000
# Epoch 121 : Train Loss 0.149082 , Train acc 0.978000, Valid acc 0.850000
# Epoch 131 : Train Loss 0.149019 , Train acc 0.978000, Valid acc 0.850000
# Epoch 141 : Train Loss 0.148945 , Train acc 0.978000, Valid acc 0.850000
# Epoch 151 : Train Loss 0.148859 , Train acc 0.980000, Valid acc 0.848000
# Epoch 161 : Train Loss 0.148777 , Train acc 0.980000, Valid acc 0.850000
# Epoch 171 : Train Loss 0.148668 , Train acc 0.982000, Valid acc 0.850000
# Epoch 181 : Train Loss 0.148577 , Train acc 0.982000, Valid acc 0.850000
# Epoch 191 : Train Loss 0.148492 , Train acc 0.982000, Valid acc 0.848000
# Epoch 201 : Train Loss 0.148390 , Train acc 0.983000, Valid acc 0.848000
# Epoch 211 : Train Loss 0.148346 , Train acc 0.983000, Valid acc 0.848000
# Epoch 221 : Train Loss 0.148309 , Train acc 0.983000, Valid acc 0.848000
# Epoch 231 : Train Loss 0.148276 , Train acc 0.983000, Valid acc 0.850000
# Epoch 241 : Train Loss 0.148245 , Train acc 0.983000, Valid acc 0.850000
# Epoch 251 : Train Loss 0.148217 , Train acc 0.983000, Valid acc 0.850000
# Epoch 261 : Train Loss 0.148191 , Train acc 0.983000, Valid acc 0.850000
# Epoch 271 : Train Loss 0.148168 , Train acc 0.983000, Valid acc 0.850000
# Epoch 281 : Train Loss 0.148145 , Train acc 0.983000, Valid acc 0.850000
# Epoch 291 : Train Loss 0.148125 , Train acc 0.983000, Valid acc 0.852000
# Epoch 301 : Train Loss 0.148106 , Train acc 0.983000, Valid acc 0.850000
# Epoch 311 : Train Loss 0.148088 , Train acc 0.983000, Valid acc 0.852000
# Epoch 321 : Train Loss 0.148071 , Train acc 0.983000, Valid acc 0.850000
# Epoch 331 : Train Loss 0.148055 , Train acc 0.983000, Valid acc 0.852000
# Epoch 341 : Train Loss 0.148040 , Train acc 0.983000, Valid acc 0.852000
# Epoch 351 : Train Loss 0.148026 , Train acc 0.983000, Valid acc 0.852000
# Epoch 361 : Train Loss 0.148013 , Train acc 0.983000, Valid acc 0.852000
# Epoch 371 : Train Loss 0.148001 , Train acc 0.983000, Valid acc 0.852000
# Epoch 381 : Train Loss 0.147989 , Train acc 0.983000, Valid acc 0.852000

# %% [markdown]
# # Assignments
#
# Try and add these modifications (might require some Googleing -- an important skill in deep learning):
# - Kaiming He initialization instead of Xavier Glorot
# - add an extra layer
# - use the relu activation function
# - add momentum to the optimizer
# - use the ADAM optimizer instead of stochastic gradient descent
#
# ### Advanced - Regularization
#
# Regularization is VERY important in practice and is used practically every time.
# Many important results are completely dependent on cleaver use of regularization, and it is something you need to become familiar with if you want to work with deep learning.
#
# - add L1 or L2 weight regularization (aka. weight decay)
# - add dropout to the network (**note** the `net.train()` and `net.eval()` are already in the code)
# - add batchnorm
#
# __Pointers on regularization hyperparameter:__
# 1. L2 and [L1 regularization](http://pytorch.org/docs/master/nn.html#torch.nn.L1Loss) (weight decay of optimization functions)
#   - Normal ranges: 1e-4  -  1e-8
# 1. [Dropout](http://pytorch.org/docs/master/nn.html?highlight=dropout#torch.nn.Dropout). Dropout rate 0.1-0.5
#   - Remember to pick the correct version according to the input dimensionality
#   - **NOTE** call `net.train()` before training to activate random dropout, and call `net.eval()` to deactivate dropout while validating or running inference with model.
# 1. [Batchnorm](http://pytorch.org/docs/master/nn.html#torch.nn.BatchNorm1d): Batchnorm also acts as a regularizer - Often very useful (faster and better convergence)
#   - Remember to pick the correct version according to the input dimensionality
#   - **NOTE** call `net.train()` before training to activate, and call `net.eval()` to have a non-stochastic variant while validating or running inference with model.

# %% [markdown]
# You are done for now. [Good job.](https://media1.tenor.com/images/0fd559b07f2174f9b8b7dbde7c5a67ca/tenor.gif)

# %% [markdown]
# ## Assignment comments
#
# All the modifications on the network and the optimizer are notified by comment in the code. The following table contains the results obtained with different regularization technics. ( with $batch\_size = 64$ and $num\_epochs = 200$)

# %% [markdown]
# | Regularization technic        | Train accuracy           | Validation accuracy  |
# | ------------- |:-------------:| -----:|
# | None      |  0.991 | 0.875 |
# | L2 1e-4      |   0.991    | 0.872  |
# | L2 1e-6 |    0.993   |   0.876  |
# | L2 1e-8 |    0.993   |   0.875  |
# | Dropout p=0.2 |    0.986    |  0.860   |
# | Dropout p=0.5 |   0.985     |   0.855  |
# | Batchnorm |   1.000     |  0.872   |
# | All together |    1.000    |   0.867  |

# %% [markdown]
# ### Comments
#
# * Without regularization: there is a bit of overfitting as validation curve goes down at the end but not significantly.
# * L2: results are allmost the same as without regularization, the validation accuracy reaches the sames values at a similar pace.
# * Dropout: with dropout, the network takes more epochs to converge and the bigger $p$ is the bigger number of epoch recquired to converge is. With $p=0.2$ allmost $400$ epochs but $600$ with $p=0.5$. However with dropout, the validation curve is really noisy especially with great values for $p$. This could be explained by the fact that some of the neurons' activations in the network are set to $0$ randomly, then it could suit a bit better or less the validation set. Using Dropout, the curve trend might more relevant than the validation accuracy of the last epoch.
# * Batchnorm: converge very rapidly in comparison with Dropout and validation is always improving even after a great number of epochs ($600$).
# * All together: as dropout is activated, it takes a long time to converge.
#
# Something a bit strange happened during my tests. I tried to take more data in the training set ($10000$ examples), everything went right except when I tried to train the network with both Dropout and Batchnorm. I get an a memory leak error from Cuda after $70$ epochs and each time it stops exactly at the same point. I tried to google it but I did not find anything yet. If you have any idea how to solve this I would be glad to hear it.

# %% [markdown]
# ### Exercise from Michael Nielson's book
#
# * Prove the assertion: the choice of $\Delta v$ which minimizes $\nabla C . \Delta v$ is $\Delta v = - \eta\nabla C$, where $\eta = \frac{\epsilon}{\|\nabla C\|}$.
#
# * I explained gradient descent when $C$ is a function of two variables, and when it's a function of more than two variables. What happens when $C$ is a function of just one variable? Can you provide a geometric interpretation of what gradient descent is doing in the one-dimensional case?

# %% [markdown]
# #### Answer
#
# * First, we apply Cauchy-Schwarz inequality to the dot product $\nabla C . \Delta v$ which gives: $|\nabla C . \Delta v| \leq \| \nabla C\| . \| \Delta v\|$, hence $ - \| \nabla C\| . \| \Delta v\| \leq \nabla C . \Delta v$. The equality is reached when the two vectors are linearly dependant, which means that $\Delta v = \lambda . \nabla C$.
#
# Then, $$\begin{gather*}
#             - \| \nabla C\| . \| \Delta v\| = \nabla C . \Delta v \\
#             - \| \nabla C\| . \epsilon = \nabla C . \lambda . \nabla C \\
#             - \| \nabla C\| . \epsilon = \lambda . \|\nabla C\|^2 \\
#             \lambda = - \frac{ \epsilon}{\| \nabla C\|}
#        \end{gather*}$$
#
# Finally, with $\eta = - \lambda$, we have $\Delta v = - \eta\nabla C$.

# %% [markdown]
# * If $C$ is a function of one variable, gradient descent will just goes down step by step until it reaches a local minimum (if there exists one, else it will go down indefinitely). Its steps will be proportionnal to the slope of C's curve.
